# %%
import os
import pickle
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"device: {device}")
# Out:
# device: cuda

# %%
video_path = r"C:\Users\User\Desktop\deeplearning\fusion\video_features_768.pkl"
audio_path = r"C:\Users\User\Desktop\deeplearning\fusion\audio_hubert_768.pkl"
text_path = r"C:\Users\User\Desktop\deeplearning\fusion\text_features_768(증강+동결6+earlystop)_수정버전.pkl"

# 2199개 샘플, 이미지 높이 224, 이미지 너비 224, RGB 3채널
with open(video_path, "rb") as f: 
    video_data = pickle.load(f)
X_video = video_data["features"]
X_video_labels = video_data["labels"] 



with open(audio_path, "rb") as f:
    audio_data = pickle.load(f)
X_audio = audio_data["audio_feat"]
X_audio_labels = audio_data["labels"]


text_data = torch.load(text_path,map_location=device)
X_text = text_data["features"]
X_text_labels = text_data["labels"]

# with open(text_path, "rb") as f:
#     text_data = pickle.load(f)
# X_text = text_data["features"]
# X_text_labels = text_data["labels"]

X_video_labels = torch.as_tensor(X_video_labels).long()
X_audio_labels = torch.as_tensor(X_audio_labels).long()
X_text_labels = torch.as_tensor(X_text_labels).long()


print(f"X_video      : {X_video.shape} ") # (224, 224, 3)
print(f"X_video_labels: (긍정 {X_video_labels.sum()} / 부정 {(X_video_labels==0).sum()})")

print(f"X_audio      : {X_audio.shape} ")
print(f"X_audio_labels: (긍정 {X_audio_labels.sum()} / 부정 {(X_audio_labels==0).sum()})")

print(f"X_text      : {X_text.shape} ")
print(f"X_text_labels: (긍정 {X_text_labels.sum()} / 부정 {(X_text_labels==0).sum()})")
# Out:
# X_video      : torch.Size([2199, 768])
# X_video_labels: (긍정 1080 / 부정 1119)
# X_audio      : torch.Size([2199, 768])
# X_audio_labels: (긍정 1080 / 부정 1119)
# X_text      : torch.Size([2199, 768])
# X_text_labels: (긍정 1080 / 부정 1119)

# %% [markdown]
# 그러나 라벨 분포가 video만 다르다

# %%
X_video_labels = torch.as_tensor(X_video_labels).cpu()
X_audio_labels = torch.as_tensor(X_audio_labels).cpu()
X_text_labels = torch.as_tensor(X_text_labels).cpu()

print(torch.equal(X_audio_labels, X_text_labels))
print(torch.equal(X_video_labels, X_text_labels))
print(torch.equal(X_video_labels, X_audio_labels))
# Out:
# True
# False
# False

# %% [markdown]
# feature 차원 기준 concat은 가능하나 label 기준 video 라벨이 달라 확인 필요
# 각자 차원수 맞춰왔으니 각 모달리티별 인코더 생략 가능

# %%
import torch.nn as nn

X_video = X_video.to(device)
X_audio = X_audio.to(device)
X_text = X_text.to(device)

# 세 모달리티 concat → MLP
fused = torch.cat([X_video, X_audio, X_text], dim=1)  # (N, 768)

input_dim = fused.shape[1]  # 768 + 768 + 768 = 2304


mlp = nn.Sequential(
    nn.Linear(input_dim, 256), 
    nn.ReLU(), 
    nn.Dropout(0.3),
    nn.Linear(256, 2)
)

y = torch.as_tensor(X_text_labels).long().to(device)  # (N,)

print(fused.shape)  # (N, 2304)
print(y.shape)
print(fused.device)
# Out:
# torch.Size([2199, 2304])
# torch.Size([2199])
# cuda:0

# %%
# train / val / test split
N = fused.shape[0]
indices = torch.randperm(N,device=device)

train_size = int(0.7 * N)
val_size = int(0.15 * N)

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size + val_size]
test_idx = indices[train_size + val_size:]

X_train, y_train = fused[train_idx], y[train_idx]
X_val, y_val = fused[val_idx], y[val_idx]
X_test, y_test = fused[test_idx], y[test_idx]

# %%
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score

# %%
#DataLoader
batch_size = 32

train_loader = DataLoader(
    TensorDataset(X_train, y_train),
    batch_size=32,
    shuffle=True
)

val_loader = DataLoader(
    TensorDataset(X_val, y_val),
    batch_size=32,
    shuffle=False
)
test_loader = DataLoader(
    TensorDataset(X_test, y_test),
    batch_size=32,
    shuffle=False
)

# %%
MLP = nn.Sequential(
    nn.Linear(input_dim, 256), 
    nn.BatchNorm1d(256),
    nn.ReLU(), 
    nn.Dropout(0.5),
    nn.Linear(256, 3)
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(MLP.parameters(), lr=1e-3)

# %%
def evaluate(model, data_loader):
    model.eval()
    all_preds = []
    all_labels = []
    total_loss = 0

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            total_loss += loss.item() 

            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y_batch.cpu().numpy())

    avg_loss = total_loss / len(data_loader)
    acc = accuracy_score(all_labels, all_preds)
    prec = precision_score(all_labels, all_preds)
    rec = recall_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    
    return avg_loss, acc, prec, rec, f1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
mlp = mlp.to(device)

optimizer = optim.Adam(mlp.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

train_losses = []
val_losses = []


epochs = 20

for epoch in range(epochs):
    mlp.train()
    total_loss = 0

for X_batch, y_batch in train_loader:
    X_batch = X_batch.to(device)
    y_batch = y_batch.to(device)

    optimizer.zero_grad()

    outputs = mlp(X_batch)
    loss = criterion(outputs, y_batch)

    loss.backward()
    optimizer.step()

# %%
print(next(mlp.parameters()).device)
print(fused.device)
# Out:
# cuda:0
# cuda:0

# %%
mlp = mlp.to(fused.device)
optimizer = optim.Adam(mlp.parameters(), lr=1e-3)

print(next(mlp.parameters()).device)
print(fused.device)
# Out:
# cuda:0
# cuda:0

# %%
history = {
    "train_loss": [],
    "train_acc": [],
    "train_prec": [],
    "train_rec": [],
    "train_f1": [], 

    "val_loss": [],
    "val_acc": [],
    "val_prec": [],
    "val_rec": [],
    "val_f1": [],

    "test_loss": [],
    "test_acc": [],
    "test_prec": [],
    "test_rec": [],
    "test_f1": []
}

epochs = 20

# Early Stopping
best_val_loss = float("inf")
patience_counter = 0
patience = 4  
best_model_state = None
best_epoch = 0


for epoch in range(epochs):
    mlp.train()
    
    total_loss = 0

    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()

        outputs = mlp(X_batch)
        loss = criterion(outputs, y_batch)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    train_loss = total_loss / len(train_loader)

    train_loss, train_acc, train_prec, train_rec, train_f1 = evaluate(mlp, train_loader)
    val_loss, val_acc, val_prec, val_rec, val_f1 = evaluate(mlp, val_loader)
    test_loss, test_acc, test_prec, test_rec, test_f1 = evaluate(mlp, test_loader)

    # print(f"Epoch {epoch+1}/{epochs} ")
    # print(f"Loss: {train_loss:.4f} ")
    # print(f"Val Acc: {val_acc:.4f} ")
    # print(f"Val Prec: {val_prec:.4f} ")
    # print(f"Val Rec: {val_rec:.4f} ")
    # print(f"Val F1: {val_f1:.4f}")

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["train_prec"].append(train_prec)
    history["train_rec"].append(train_rec)
    history["train_f1"].append(train_f1)

    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)
    history["val_prec"].append(val_prec)
    history["val_rec"].append(val_rec)
    history["val_f1"].append(val_f1)

    history["test_loss"].append(test_loss)
    history["test_acc"].append(test_acc)
    history["test_prec"].append(test_prec)
    history["test_rec"].append(test_rec)
    history["test_f1"].append(test_f1)

    # Early Stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = mlp.state_dict().copy()
        best_epoch = epoch
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f} - Val Acc: {val_acc:.4f} - Val Prec: {val_prec:.4f} - Val Rec: {val_rec:.4f} - Val F1: {val_f1:.4f}")
# 가장 성능 좋은 모델 불러오기 (early stopping 기준)
mlp.load_state_dict(best_model_state)

train_loss, train_acc, train_prec, train_rec, train_f1 = evaluate(mlp, train_loader)
val_loss, val_acc, val_prec, val_rec, val_f1 = evaluate(mlp, val_loader)
test_loss, test_acc, test_prec, test_rec, test_f1 = evaluate(mlp, test_loader)

print("\n=====================결과=====================")
print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} ,Train Prec: {train_prec:.4f} ,Train Rec: {train_rec:.4f} ,Train F1: {train_f1:.4f}")
print(f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f} ,Val Prec: {val_prec:.4f} ,Val Rec: {val_rec:.4f} ,Val F1: {val_f1:.4f}")
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f} ,Test Prec: {test_prec:.4f} ,Test Rec: {test_rec:.4f} ,Test F1: {test_f1:.4f}")
# Out:
# Epoch 1/20 - Train Loss: 0.2540 - Val Loss: 0.2511 - Val Acc: 0.8815 - Val Prec: 0.8790 - Val Rec: 0.8734 - Val F1: 0.8762
# Epoch 2/20 - Train Loss: 0.2493 - Val Loss: 0.2527 - Val Acc: 0.8815 - Val Prec: 0.8940 - Val Rec: 0.8544 - Val F1: 0.8738
# Epoch 3/20 - Train Loss: 0.2392 - Val Loss: 0.2470 - Val Acc: 0.8936 - Val Prec: 0.9241 - Val Rec: 0.8481 - Val F1: 0.8845
# Epoch 4/20 - Train Loss: 0.2333 - Val Loss: 0.2553 - Val Acc: 0.8784 - Val Prec: 0.9275 - Val Rec: 0.8101 - Val F1: 0.8649
# Epoch 5/20 - Train Loss: 0.2382 - Val Loss: 0.2525 - Val Acc: 0.8936 - Val Prec: 0.8727 - Val Rec: 0.9114 - Val F1: 0.8916
# Epoch 6/20 - Train Loss: 0.2167 - Val Loss: 0.2476 - Val Acc: 0.8936 - Val Prec: 0.9128 - Val Rec: 0.8608 - Val F1: 0.8860
# Epoch 7/20 - Train Loss: 0.2031 - Val Loss: 0.2423 - Val Acc: 0.8906 - Val Prec: 0.8861 - Val Rec: 0.8861 - Val F1: 0.8861
# Epoch 8/20 - Train Loss: 0.1967 - Val Loss: 0.2457 - Val Acc: 0.8815 - Val Prec: 0.8940 - Val Rec: 0.8544 - Val F1: 0.8738
# Epoch 9/20 - Train Loss: 0.1945 - Val Loss: 0.2498 - Val Acc: 0.8784 - Val Prec: 0.9041 - Val Rec: 0.8354 - Val F1: 0.8684
# Epoch 10/20 - Train Loss: 0.2052 - Val Loss: 0.2600 - Val Acc: 0.8875 - Val Prec: 0.8580 - Val Rec: 0.9177 - Val F1: 0.8869
# Early stopping at epoch 11
#
# =====================결과=====================
# Train Loss: 0.1720, Train Acc: 0.9298 ,Train Prec: 0.9207 ,Train Rec: 0.9356 ,Train F1: 0.9281
# Val Loss: 0.2510, Val Acc: 0.8875 ,Val Prec: 0.8805 ,Val Rec: 0.8861 ,Val F1: 0.8833
# Test Loss: 0.1899, Test Acc: 0.9154 ,Test Prec: 0.9306 ,Test Rec: 0.9096 ,Test F1: 0.9200

# %%
import matplotlib.pyplot as plt
import numpy as np

# ============
# x축 epoch 설정
# ============
epochs_range = range(1, len(history["train_loss"]) + 1)

# ============
# 0~1 값을 0~ 100 퍼센트로 변환
# ============
def to_percentage(values):
    values = np.array(values)
    if values.max() <= 1.5:
        return values * 100
    return values

train_acc = to_percentage(history["train_acc"])
val_acc = to_percentage(history["val_acc"])
test_acc = to_percentage(history["test_acc"])

train_f1 = to_percentage(history["train_f1"])
val_f1 = to_percentage(history["val_f1"])
test_f1 = to_percentage(history["test_f1"])

plt.figure(figsize=(18, 5))
plt.suptitle("MLP Middle Fusion(768)_augmentation+freeze6+earlystop", fontsize=14)


# ============
# Loss 그래프 그리기
# ============

plt.subplot(1, 3, 1)

plt.plot(epochs_range, history["train_loss"], label="Train Loss")
plt.plot(epochs_range, history["val_loss"], linestyle="--", label="Val Loss")
plt.plot(epochs_range, history["test_loss"], linestyle=":", label="Test Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curves")
plt.legend()
plt.grid(True)


# ============
# Accuracy 그래프 그리기
# ============
plt.subplot(1, 3, 2)

plt.plot(epochs_range, train_acc, label="Train Accuracy")
plt.plot(epochs_range, val_acc, linestyle="--", label="Val Accuracy")
plt.plot(epochs_range, test_acc, linestyle=":", label="Test Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy Curves")
plt.legend()
plt.grid(True)

# ============
# F1 Score 그래프 그리기
# ============

plt.subplot(1, 3, 3)

plt.plot(epochs_range, train_f1, label="Train F1 Score")
plt.plot(epochs_range, val_f1, linestyle="--", label="Val F1 Score")
plt.plot(epochs_range, test_f1, linestyle=":", label="Test F1 Score")

plt.xlabel("Epoch")
plt.ylabel("F1 Score")
plt.title("F1 Score Curves")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# %%
# ============================================================
# Modality Ablation Study
# Text / Audio / Video / Fusion 조합 비교
# ============================================================

feature_sets = {
    "Text only": X_text,
    "Audio only": X_audio,
    "Video only": X_video,
    "Text + Audio": torch.cat([X_text, X_audio], dim=1),
    "Text + Video": torch.cat([X_text, X_video], dim=1),
    "Audio + Video": torch.cat([X_audio, X_video], dim=1),
    "Text + Audio + Video": torch.cat([X_text, X_audio, X_video], dim=1)
}

results = []

for model_name, fused in feature_sets.items():
    print("\n==============================")
    print(f"Training: {model_name}")
    print("==============================")

    input_dim = fused.shape[1]

    # 기존과 같은 split 사용
    X_train = fused[train_idx]
    y_train = y[train_idx]

    X_val = fused[val_idx]
    y_val = y[val_idx]

    X_test = fused[test_idx]
    y_test = y[test_idx]

    train_loader = DataLoader(
        TensorDataset(X_train, y_train),
        batch_size=32,
        shuffle=True
    )

    val_loader = DataLoader(
        TensorDataset(X_val, y_val),
        batch_size=32,
        shuffle=False
    )

    test_loader = DataLoader(
        TensorDataset(X_test, y_test),
        batch_size=32,
        shuffle=False
    )

    # 기존 MLP 구조 그대로 사용
    mlp = nn.Sequential(
        nn.Linear(input_dim, 256),
        nn.ReLU(),
        nn.Dropout(0.3),
        nn.Linear(256, 2)
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(mlp.parameters(), lr=0.001)

    best_val_loss = float("inf")
    best_model_state = None

    for epoch in range(20):
        mlp.train()
        train_loss = 0

        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()

            outputs = mlp(X_batch)
            loss = criterion(outputs, y_batch)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        val_loss, val_acc, val_prec, val_rec, val_f1 = evaluate(mlp, val_loader)

        print(
            f"Epoch [{epoch+1}/20] "
            f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, Val F1: {val_f1:.4f}"
        )

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = mlp.state_dict()

    # best validation 모델로 test 평가
    mlp.load_state_dict(best_model_state)

    test_loss, test_acc, test_prec, test_rec, test_f1 = evaluate(mlp, test_loader)

    results.append({
        "Model": model_name,
        "Input Dim": input_dim,
        "Test Loss": test_loss,
        "Test Acc": test_acc,
        "Test Precision": test_prec,
        "Test Recall": test_rec,
        "Test F1": test_f1
    })

# 결과표 확인
results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by="Test F1", ascending=False)

results_df
# Out:
# ==============================
# Training: Text only
# ==============================
# Epoch [1/20] Val Loss: 0.2553, Val Acc: 0.8936, Val F1: 0.8903
# Epoch [2/20] Val Loss: 0.2541, Val Acc: 0.8875, Val F1: 0.8795
# Epoch [3/20] Val Loss: 0.2765, Val Acc: 0.8784, Val F1: 0.8658
# Epoch [4/20] Val Loss: 0.2674, Val Acc: 0.8815, Val F1: 0.8721
# Epoch [5/20] Val Loss: 0.2523, Val Acc: 0.8936, Val F1: 0.8867
# Epoch [6/20] Val Loss: 0.2484, Val Acc: 0.8967, Val F1: 0.8917
# Epoch [7/20] Val Loss: 0.2483, Val Acc: 0.8967, Val F1: 0.8924
# Epoch [8/20] Val Loss: 0.2502, Val Acc: 0.8906, Val F1: 0.8839
# Epoch [9/20] Val Loss: 0.2476, Val Acc: 0.8967, Val F1: 0.8924
# Epoch [10/20] Val Loss: 0.2497, Val Acc: 0.8906, Val F1: 0.8839
# Epoch [11/20] Val Loss: 0.2472, Val Acc: 0.8967, Val F1: 0.8917
# Epoch [12/20] Val Loss: 0.2539, Val Acc: 0.8936, Val F1: 0.8875
# Epoch [13/20] Val Loss: 0.2508, Val Acc: 0.8906, Val F1: 0.8839
# Epoch [14/20] Val Loss: 0.2477, Val Acc: 0.8997, Val F1: 0.8946
# Epoch [15/20] Val Loss: 0.2572, Val Acc: 0.8815, Val F1: 0.8713
# Epoch [16/20] Val Loss: 0.2481, Val Acc: 0.8997, Val F1: 0.8946
# Epoch [17/20] Val Loss: 0.2568, Val Acc: 0.8815, Val F1: 0.8713
# Epoch [18/20] Val Loss: 0.2533, Val Acc: 0.8936, Val F1: 0.8875
# Epoch [19/20] Val Loss: 0.2546, Val Acc: 0.8936, Val F1: 0.8875
# Epoch [20/20] Val Loss: 0.2541, Val Acc: 0.8875, Val F1: 0.8795
#
# ==============================
# Training: Audio only
# ==============================
# Epoch [1/20] Val Loss: 0.6682, Val Acc: 0.5927, Val F1: 0.6398
# Epoch [2/20] Val Loss: 0.6511, Val Acc: 0.6018, Val F1: 0.3850
# Epoch [3/20] Val Loss: 0.6962, Val Acc: 0.5623, Val F1: 0.6697
# Epoch [4/20] Val Loss: 0.6208, Val Acc: 0.6596, Val F1: 0.6267
# Epoch [5/20] Val Loss: 0.6415, Val Acc: 0.6231, Val F1: 0.6477
# Epoch [6/20] Val Loss: 0.6292, Val Acc: 0.6687, Val F1: 0.6065
# Epoch [7/20] Val Loss: 0.6236, Val Acc: 0.6687, Val F1: 0.6175
# Epoch [8/20] Val Loss: 0.6643, Val Acc: 0.6322, Val F1: 0.6807
# Epoch [9/20] Val Loss: 0.6561, Val Acc: 0.6353, Val F1: 0.6774
# Epoch [10/20] Val Loss: 0.6316, Val Acc: 0.6596, Val F1: 0.6056
# Epoch [11/20] Val Loss: 0.6388, Val Acc: 0.6626, Val F1: 0.5904
# Epoch [12/20] Val Loss: 0.7143, Val Acc: 0.6170, Val F1: 0.6818
# Epoch [13/20] Val Loss: 0.6266, Val Acc: 0.6626, Val F1: 0.6263
# Epoch [14/20] Val Loss: 0.6340, Val Acc: 0.6565, Val F1: 0.6627
# Epoch [15/20] Val Loss: 0.6404, Val Acc: 0.6413, Val F1: 0.5845
# Epoch [16/20] Val Loss: 0.6386, Val Acc: 0.6596, Val F1: 0.6084
# Epoch [17/20] Val Loss: 0.6483, Val Acc: 0.6474, Val F1: 0.6442
# Epoch [18/20] Val Loss: 0.6473, Val Acc: 0.6474, Val F1: 0.6234
# Epoch [19/20] Val Loss: 0.6674, Val Acc: 0.6657, Val F1: 0.5896
# Epoch [20/20] Val Loss: 0.6708, Val Acc: 0.6565, Val F1: 0.5891
#
# ==============================
# Training: Video only
# ==============================
# Epoch [1/20] Val Loss: 0.6883, Val Acc: 0.5380, Val F1: 0.2692
# Epoch [2/20] Val Loss: 0.6955, Val Acc: 0.5562, Val F1: 0.6138
# Epoch [3/20] Val Loss: 0.6918, Val Acc: 0.5350, Val F1: 0.4093
# Epoch [4/20] Val Loss: 0.6771, Val Acc: 0.5745, Val F1: 0.6089
# Epoch [5/20] Val Loss: 0.6840, Val Acc: 0.6201, Val F1: 0.6154
# Epoch [6/20] Val Loss: 0.6825, Val Acc: 0.6018, Val F1: 0.6090
# Epoch [7/20] Val Loss: 0.7001, Val Acc: 0.5775, Val F1: 0.6352
# Epoch [8/20] Val Loss: 0.7553, Val Acc: 0.5593, Val F1: 0.6455
# Epoch [9/20] Val Loss: 0.7304, Val Acc: 0.5623, Val F1: 0.5135
# Epoch [10/20] Val Loss: 0.7284, Val Acc: 0.6079, Val F1: 0.6387
# Epoch [11/20] Val Loss: 0.7263, Val Acc: 0.5836, Val F1: 0.5508
# Epoch [12/20] Val Loss: 0.7320, Val Acc: 0.5988, Val F1: 0.5182
# Epoch [13/20] Val Loss: 0.7487, Val Acc: 0.5897, Val F1: 0.5794
# Epoch [14/20] Val Loss: 0.7359, Val Acc: 0.5897, Val F1: 0.5574
# Epoch [15/20] Val Loss: 0.7505, Val Acc: 0.5684, Val F1: 0.5035
# Epoch [16/20] Val Loss: 0.7774, Val Acc: 0.5927, Val F1: 0.5915
# Epoch [17/20] Val Loss: 0.7672, Val Acc: 0.5684, Val F1: 0.5535
# Epoch [18/20] Val Loss: 0.7781, Val Acc: 0.5714, Val F1: 0.4982
# Epoch [19/20] Val Loss: 0.8507, Val Acc: 0.5897, Val F1: 0.6064
# Epoch [20/20] Val Loss: 0.8134, Val Acc: 0.6018, Val F1: 0.5677
#
# ==============================
# Training: Text + Audio
# ==============================
# Epoch [1/20] Val Loss: 0.2643, Val Acc: 0.8906, Val F1: 0.8831
# Epoch [2/20] Val Loss: 0.2580, Val Acc: 0.8784, Val F1: 0.8675
# Epoch [3/20] Val Loss: 0.2551, Val Acc: 0.8906, Val F1: 0.8831
# Epoch [4/20] Val Loss: 0.2457, Val Acc: 0.8997, Val F1: 0.8959
# Epoch [5/20] Val Loss: 0.2490, Val Acc: 0.8967, Val F1: 0.8917
# Epoch [6/20] Val Loss: 0.2560, Val Acc: 0.8906, Val F1: 0.8816
# Epoch [7/20] Val Loss: 0.2400, Val Acc: 0.8967, Val F1: 0.8917
# Epoch [8/20] Val Loss: 0.2489, Val Acc: 0.8967, Val F1: 0.8917
# Epoch [9/20] Val Loss: 0.2592, Val Acc: 0.8845, Val F1: 0.8733
# Epoch [10/20] Val Loss: 0.2526, Val Acc: 0.8875, Val F1: 0.8779
# Epoch [11/20] Val Loss: 0.2539, Val Acc: 0.8845, Val F1: 0.8742
# Epoch [12/20] Val Loss: 0.2413, Val Acc: 0.8967, Val F1: 0.8924
# Epoch [13/20] Val Loss: 0.2504, Val Acc: 0.8875, Val F1: 0.8779
# Epoch [14/20] Val Loss: 0.2590, Val Acc: 0.8906, Val F1: 0.8800
# Epoch [15/20] Val Loss: 0.2429, Val Acc: 0.8997, Val F1: 0.8952
# Epoch [16/20] Val Loss: 0.2418, Val Acc: 0.9027, Val F1: 0.8981
# Epoch [17/20] Val Loss: 0.2471, Val Acc: 0.9027, Val F1: 0.8987
# Epoch [18/20] Val Loss: 0.2403, Val Acc: 0.8997, Val F1: 0.8952
# Epoch [19/20] Val Loss: 0.2395, Val Acc: 0.9088, Val F1: 0.9038
# Epoch [20/20] Val Loss: 0.2640, Val Acc: 0.8936, Val F1: 0.8860
#
# ==============================
# Training: Text + Video
# ==============================
# Epoch [1/20] Val Loss: 0.2522, Val Acc: 0.8906, Val F1: 0.8846
# Epoch [2/20] Val Loss: 0.2488, Val Acc: 0.8845, Val F1: 0.8766
# Epoch [3/20] Val Loss: 0.2623, Val Acc: 0.8906, Val F1: 0.8824
# Epoch [4/20] Val Loss: 0.2473, Val Acc: 0.8875, Val F1: 0.8840
# Epoch [5/20] Val Loss: 0.2507, Val Acc: 0.8875, Val F1: 0.8833
# Epoch [6/20] Val Loss: 0.2607, Val Acc: 0.8845, Val F1: 0.8742
# Epoch [7/20] Val Loss: 0.2502, Val Acc: 0.8906, Val F1: 0.8868
# Epoch [8/20] Val Loss: 0.2570, Val Acc: 0.8936, Val F1: 0.8903
# Epoch [9/20] Val Loss: 0.2726, Val Acc: 0.8754, Val F1: 0.8629
# Epoch [10/20] Val Loss: 0.2771, Val Acc: 0.8875, Val F1: 0.8779
# Epoch [11/20] Val Loss: 0.2555, Val Acc: 0.8754, Val F1: 0.8690
# Epoch [12/20] Val Loss: 0.2640, Val Acc: 0.8815, Val F1: 0.8721
# Epoch [13/20] Val Loss: 0.2570, Val Acc: 0.8845, Val F1: 0.8758
# Epoch [14/20] Val Loss: 0.2638, Val Acc: 0.8723, Val F1: 0.8679
# Epoch [15/20] Val Loss: 0.2855, Val Acc: 0.8875, Val F1: 0.8771
# Epoch [16/20] Val Loss: 0.2653, Val Acc: 0.8723, Val F1: 0.8627
# Epoch [17/20] Val Loss: 0.2627, Val Acc: 0.8936, Val F1: 0.8867
# Epoch [18/20] Val Loss: 0.2510, Val Acc: 0.8815, Val F1: 0.8762
# Epoch [19/20] Val Loss: 0.2855, Val Acc: 0.8754, Val F1: 0.8629
# Epoch [20/20] Val Loss: 0.2799, Val Acc: 0.8815, Val F1: 0.8713
#
# ==============================
# Training: Audio + Video
# ==============================
# Epoch [1/20] Val Loss: 0.6779, Val Acc: 0.5684, Val F1: 0.5989
# Epoch [2/20] Val Loss: 0.6614, Val Acc: 0.6079, Val F1: 0.5536
# Epoch [3/20] Val Loss: 0.6713, Val Acc: 0.5988, Val F1: 0.6432
# Epoch [4/20] Val Loss: 0.6527, Val Acc: 0.6322, Val F1: 0.5926
# Epoch [5/20] Val Loss: 0.6710, Val Acc: 0.6231, Val F1: 0.5441
# Epoch [6/20] Val Loss: 0.7346, Val Acc: 0.5775, Val F1: 0.6634
# Epoch [7/20] Val Loss: 0.7065, Val Acc: 0.6261, Val F1: 0.6328
# Epoch [8/20] Val Loss: 0.7151, Val Acc: 0.6018, Val F1: 0.5498
# Epoch [9/20] Val Loss: 0.7495, Val Acc: 0.5927, Val F1: 0.4417
# Epoch [10/20] Val Loss: 0.7315, Val Acc: 0.6535, Val F1: 0.6014
# Epoch [11/20] Val Loss: 0.7016, Val Acc: 0.6383, Val F1: 0.6270
# Epoch [12/20] Val Loss: 0.8087, Val Acc: 0.5805, Val F1: 0.6290
# Epoch [13/20] Val Loss: 0.8040, Val Acc: 0.5714, Val F1: 0.4982
# Epoch [14/20] Val Loss: 0.7566, Val Acc: 0.6353, Val F1: 0.5973
# Epoch [15/20] Val Loss: 0.7366, Val Acc: 0.6444, Val F1: 0.6444
# Epoch [16/20] Val Loss: 0.7631, Val Acc: 0.6292, Val F1: 0.5643
# Epoch [17/20] Val Loss: 0.7645, Val Acc: 0.6444, Val F1: 0.6262
# Epoch [18/20] Val Loss: 0.8151, Val Acc: 0.6140, Val F1: 0.6092
# Epoch [19/20] Val Loss: 0.7998, Val Acc: 0.6535, Val F1: 0.6503
# Epoch [20/20] Val Loss: 0.8428, Val Acc: 0.6079, Val F1: 0.5657
#
# ==============================
# Training: Text + Audio + Video
# ==============================
# Epoch [1/20] Val Loss: 0.2517, Val Acc: 0.8967, Val F1: 0.8931
# Epoch [2/20] Val Loss: 0.2463, Val Acc: 0.8875, Val F1: 0.8818
# Epoch [3/20] Val Loss: 0.2446, Val Acc: 0.8906, Val F1: 0.8861
# Epoch [4/20] Val Loss: 0.2484, Val Acc: 0.8906, Val F1: 0.8816
# Epoch [5/20] Val Loss: 0.2572, Val Acc: 0.8784, Val F1: 0.8658
# Epoch [6/20] Val Loss: 0.2635, Val Acc: 0.8845, Val F1: 0.8733
# Epoch [7/20] Val Loss: 0.2462, Val Acc: 0.8936, Val F1: 0.8882
# Epoch [8/20] Val Loss: 0.2538, Val Acc: 0.8906, Val F1: 0.8831
# Epoch [9/20] Val Loss: 0.2473, Val Acc: 0.8906, Val F1: 0.8889
# Epoch [10/20] Val Loss: 0.2494, Val Acc: 0.8936, Val F1: 0.8867
# Epoch [11/20] Val Loss: 0.2454, Val Acc: 0.8906, Val F1: 0.8868
# Epoch [12/20] Val Loss: 0.2753, Val Acc: 0.8906, Val F1: 0.8776
# Epoch [13/20] Val Loss: 0.2670, Val Acc: 0.8784, Val F1: 0.8667
# Epoch [14/20] Val Loss: 0.2702, Val Acc: 0.8845, Val F1: 0.8742
# Epoch [15/20] Val Loss: 0.2782, Val Acc: 0.8936, Val F1: 0.8889
# Epoch [16/20] Val Loss: 0.2553, Val Acc: 0.8906, Val F1: 0.8868
# Epoch [17/20] Val Loss: 0.2964, Val Acc: 0.8815, Val F1: 0.8669
# Epoch [18/20] Val Loss: 0.2754, Val Acc: 0.8815, Val F1: 0.8754
# Epoch [19/20] Val Loss: 0.2671, Val Acc: 0.8967, Val F1: 0.8938
# Epoch [20/20] Val Loss: 0.2617, Val Acc: 0.8936, Val F1: 0.8903
#                   Model  Input Dim  Test Loss  Test Acc  Test Precision  \
# 0             Text only        768   0.201050  0.915408        0.946108
# 4          Text + Video       1536   0.210130  0.915408        0.946108
# 6  Text + Audio + Video       2304   0.215105  0.906344        0.910112
# 3          Text + Audio       1536   0.258432  0.903323        0.939394
# 5         Audio + Video       1536   0.628980  0.694864        0.783582
# 2            Video only        768   0.660620  0.634441        0.705882
# 1            Audio only        768   0.680905  0.652568        0.771930
#
#    Test Recall   Test F1
# 0     0.892655  0.918605
# 4     0.892655  0.918605
# 6     0.915254  0.912676
# 3     0.875706  0.906433
# 5     0.593220  0.675241
# 2     0.542373  0.613419
# 1     0.497175  0.604811
