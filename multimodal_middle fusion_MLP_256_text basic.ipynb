# %%
import os
import pickle
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"device: {device}")
# Out:
# device: cuda

# %%
video_path = r"C:\Users\User\Desktop\deeplearning\fusion\video_features_256.pkl"
audio_path = r"C:\Users\User\Desktop\deeplearning\fusion\audio_feat.pkl"
text_path = r"C:\Users\User\Desktop\deeplearning\fusion\text_features_256(basic+earlystop).pkl"

# 2199개 샘플, 이미지 높이 224, 이미지 너비 224, RGB 3채널
with open(video_path, "rb") as f: 
    video_data = pickle.load(f)
X_video = video_data["features"]
X_video_labels = video_data["labels"] 



with open(audio_path, "rb") as f:
    audio_data = pickle.load(f)
X_audio = audio_data["audio_feat"]
X_audio_labels = audio_data["labels"]


text_data = torch.load(text_path,map_location=device)
X_text = text_data["features"]
X_text_labels = text_data["labels"]

# with open(text_path, "rb") as f:
#     text_data = pickle.load(f)
# X_text = text_data["features"]
# X_text_labels = text_data["labels"]

X_video_labels = torch.as_tensor(X_video_labels).long()
X_audio_labels = torch.as_tensor(X_audio_labels).long()
X_text_labels = torch.as_tensor(X_text_labels).long()


print(f"X_video      : {X_video.shape} ") # (224, 224, 3)
print(f"X_video_labels: (긍정 {X_video_labels.sum()} / 부정 {(X_video_labels==0).sum()})")

print(f"X_audio      : {X_audio.shape} ")
print(f"X_audio_labels: (긍정 {X_audio_labels.sum()} / 부정 {(X_audio_labels==0).sum()})")

print(f"X_text      : {X_text.shape} ")
print(f"X_text_labels: (긍정 {X_text_labels.sum()} / 부정 {(X_text_labels==0).sum()})")
# Out:
# X_video      : torch.Size([2199, 256])
# X_video_labels: (긍정 1176 / 부정 1023)
# X_audio      : torch.Size([2199, 256])
# X_audio_labels: (긍정 1080 / 부정 1119)
# X_text      : torch.Size([2199, 256])
# X_text_labels: (긍정 1080 / 부정 1119)

# %% [markdown]
# 그러나 라벨 분포가 video만 다르다

# %%
X_video_labels = torch.as_tensor(X_video_labels).cpu()
X_audio_labels = torch.as_tensor(X_audio_labels).cpu()
X_text_labels = torch.as_tensor(X_text_labels).cpu()

print(torch.equal(X_audio_labels, X_text_labels))
print(torch.equal(X_video_labels, X_text_labels))
print(torch.equal(X_video_labels, X_audio_labels))
# Out:
# True
# False
# False

# %% [markdown]
# feature 차원 기준 concat은 가능하나 label 기준 video 라벨이 달라 확인 필요
# 각자 차원수 맞춰왔으니 각 모달리티별 인코더 생략 가능

# %%
import torch.nn as nn

X_video = X_video.to(device)
X_audio = X_audio.to(device)
X_text = X_text.to(device)

# 세 모달리티 concat → MLP
fused = torch.cat([X_video, X_audio, X_text], dim=1)  # (N, 768)

input_dim = fused.shape[1]  # 768 + 768 + 768 = 2304


mlp = nn.Sequential(
    nn.Linear(input_dim, 256), 
    nn.ReLU(), 
    nn.Dropout(0.3),
    nn.Linear(256, 2)
)

y = torch.as_tensor(X_text_labels).long().to(device)  # (N,)

print(fused.shape)  # (N, 2304)
print(y.shape)
print(fused.device)
# Out:
# torch.Size([2199, 768])
# torch.Size([2199])
# cuda:0

# %%
# train / val / test split
N = fused.shape[0]
indices = torch.randperm(N,device=device)

train_size = int(0.7 * N)
val_size = int(0.15 * N)

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size + val_size]
test_idx = indices[train_size + val_size:]

X_train, y_train = fused[train_idx], y[train_idx]
X_val, y_val = fused[val_idx], y[val_idx]
X_test, y_test = fused[test_idx], y[test_idx]

# %%
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score

# %%
#DataLoader
batch_size = 32

train_loader = DataLoader(
    TensorDataset(X_train, y_train),
    batch_size=32,
    shuffle=True
)

val_loader = DataLoader(
    TensorDataset(X_val, y_val),
    batch_size=32,
    shuffle=False
)
test_loader = DataLoader(
    TensorDataset(X_test, y_test),
    batch_size=32,
    shuffle=False
)

# %%
MLP = nn.Sequential(
    nn.Linear(input_dim, 256), 
    nn.BatchNorm1d(256),
    nn.ReLU(), 
    nn.Dropout(0.5),
    nn.Linear(256, 3)
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(MLP.parameters(), lr=1e-3)

# %%
def evaluate(model, data_loader):
    model.eval()
    all_preds = []
    all_labels = []
    total_loss = 0

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            total_loss += loss.item() 

            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y_batch.cpu().numpy())

    avg_loss = total_loss / len(data_loader)
    acc = accuracy_score(all_labels, all_preds)
    prec = precision_score(all_labels, all_preds)
    rec = recall_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    
    return avg_loss, acc, prec, rec, f1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
mlp = mlp.to(device)

optimizer = optim.Adam(mlp.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

train_losses = []
val_losses = []


epochs = 20

for epoch in range(epochs):
    mlp.train()
    total_loss = 0

for X_batch, y_batch in train_loader:
    X_batch = X_batch.to(device)
    y_batch = y_batch.to(device)

    optimizer.zero_grad()

    outputs = mlp(X_batch)
    loss = criterion(outputs, y_batch)

    loss.backward()
    optimizer.step()

# %%
print(next(mlp.parameters()).device)
print(fused.device)
# Out:
# cuda:0
# cuda:0

# %%
mlp = mlp.to(fused.device)
optimizer = optim.Adam(mlp.parameters(), lr=1e-3)

print(next(mlp.parameters()).device)
print(fused.device)
# Out:
# cuda:0
# cuda:0

# %%
history = {
    "train_loss": [],
    "train_acc": [],
    "train_prec": [],
    "train_rec": [],
    "train_f1": [], 

    "val_loss": [],
    "val_acc": [],
    "val_prec": [],
    "val_rec": [],
    "val_f1": [],

    "test_loss": [],
    "test_acc": [],
    "test_prec": [],
    "test_rec": [],
    "test_f1": []
}

epochs = 20

# Early Stopping
best_val_loss = float("inf")
patience_counter = 0
patience = 4  
best_model_state = None
best_epoch = 0


for epoch in range(epochs):
    mlp.train()
    
    total_loss = 0

    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()

        outputs = mlp(X_batch)
        loss = criterion(outputs, y_batch)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    train_loss = total_loss / len(train_loader)

    train_loss, train_acc, train_prec, train_rec, train_f1 = evaluate(mlp, train_loader)
    val_loss, val_acc, val_prec, val_rec, val_f1 = evaluate(mlp, val_loader)
    test_loss, test_acc, test_prec, test_rec, test_f1 = evaluate(mlp, test_loader)

    # print(f"Epoch {epoch+1}/{epochs} ")
    # print(f"Loss: {train_loss:.4f} ")
    # print(f"Val Acc: {val_acc:.4f} ")
    # print(f"Val Prec: {val_prec:.4f} ")
    # print(f"Val Rec: {val_rec:.4f} ")
    # print(f"Val F1: {val_f1:.4f}")

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["train_prec"].append(train_prec)
    history["train_rec"].append(train_rec)
    history["train_f1"].append(train_f1)

    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)
    history["val_prec"].append(val_prec)
    history["val_rec"].append(val_rec)
    history["val_f1"].append(val_f1)

    history["test_loss"].append(test_loss)
    history["test_acc"].append(test_acc)
    history["test_prec"].append(test_prec)
    history["test_rec"].append(test_rec)
    history["test_f1"].append(test_f1)

    # Early Stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = mlp.state_dict().copy()
        best_epoch = epoch
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f} - Val Acc: {val_acc:.4f} - Val Prec: {val_prec:.4f} - Val Rec: {val_rec:.4f} - Val F1: {val_f1:.4f}")
# 가장 성능 좋은 모델 불러오기 (early stopping 기준)
mlp.load_state_dict(best_model_state)

train_loss, train_acc, train_prec, train_rec, train_f1 = evaluate(mlp, train_loader)
val_loss, val_acc, val_prec, val_rec, val_f1 = evaluate(mlp, val_loader)
test_loss, test_acc, test_prec, test_rec, test_f1 = evaluate(mlp, test_loader)

print("\n=====================결과=====================")
print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} ,Train Prec: {train_prec:.4f} ,Train Rec: {train_rec:.4f} ,Train F1: {train_f1:.4f}")
print(f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f} ,Val Prec: {val_prec:.4f} ,Val Rec: {val_rec:.4f} ,Val F1: {val_f1:.4f}")
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f} ,Test Prec: {test_prec:.4f} ,Test Rec: {test_rec:.4f} ,Test F1: {test_f1:.4f}")
# Out:
# Epoch 1/20 - Train Loss: 0.2424 - Val Loss: 0.2916 - Val Acc: 0.8997 - Val Prec: 0.8800 - Val Rec: 0.8980 - Val F1: 0.8889
# Epoch 2/20 - Train Loss: 0.2411 - Val Loss: 0.3013 - Val Acc: 0.8967 - Val Prec: 0.8645 - Val Rec: 0.9116 - Val F1: 0.8874
# Epoch 3/20 - Train Loss: 0.2562 - Val Loss: 0.3227 - Val Acc: 0.8815 - Val Prec: 0.8293 - Val Rec: 0.9252 - Val F1: 0.8746
# Epoch 4/20 - Train Loss: 0.2562 - Val Loss: 0.2844 - Val Acc: 0.8967 - Val Prec: 0.8742 - Val Rec: 0.8980 - Val F1: 0.8859
# Epoch 5/20 - Train Loss: 0.2386 - Val Loss: 0.2998 - Val Acc: 0.9027 - Val Prec: 0.8859 - Val Rec: 0.8980 - Val F1: 0.8919
# Epoch 6/20 - Train Loss: 0.2307 - Val Loss: 0.2919 - Val Acc: 0.8997 - Val Prec: 0.8654 - Val Rec: 0.9184 - Val F1: 0.8911
# Epoch 7/20 - Train Loss: 0.2316 - Val Loss: 0.3045 - Val Acc: 0.8936 - Val Prec: 0.8590 - Val Rec: 0.9116 - Val F1: 0.8845
# Early stopping at epoch 8
#
# =====================결과=====================
# Train Loss: 0.2327, Train Acc: 0.9201 ,Train Prec: 0.9151 ,Train Rec: 0.9258 ,Train F1: 0.9204
# Val Loss: 0.3090, Val Acc: 0.8936 ,Val Prec: 0.8544 ,Val Rec: 0.9184 ,Val F1: 0.8852
# Test Loss: 0.2547, Test Acc: 0.9063 ,Test Prec: 0.9136 ,Test Rec: 0.8970 ,Test F1: 0.9052

# %%
import matplotlib.pyplot as plt
import numpy as np

# ============
# x축 epoch 설정
# ============
epochs_range = range(1, len(history["train_loss"]) + 1)

# ============
# 0~1 값을 0~ 100 퍼센트로 변환
# ============
def to_percentage(values):
    values = np.array(values)
    if values.max() <= 1.5:
        return values * 100
    return values

train_acc = to_percentage(history["train_acc"])
val_acc = to_percentage(history["val_acc"])
test_acc = to_percentage(history["test_acc"])

train_f1 = to_percentage(history["train_f1"])
val_f1 = to_percentage(history["val_f1"])
test_f1 = to_percentage(history["test_f1"])

plt.figure(figsize=(18, 5))
plt.suptitle("MLP Middle Fusion(256)_text basic", fontsize=14)


# ============
# Loss 그래프 그리기
# ============

plt.subplot(1, 3, 1)

plt.plot(epochs_range, history["train_loss"], label="Train Loss")
plt.plot(epochs_range, history["val_loss"], linestyle="--", label="Val Loss")
plt.plot(epochs_range, history["test_loss"], linestyle=":", label="Test Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curves")
plt.legend()
plt.grid(True)


# ============
# Accuracy 그래프 그리기
# ============
plt.subplot(1, 3, 2)

plt.plot(epochs_range, train_acc, label="Train Accuracy")
plt.plot(epochs_range, val_acc, linestyle="--", label="Val Accuracy")
plt.plot(epochs_range, test_acc, linestyle=":", label="Test Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy Curves")
plt.legend()
plt.grid(True)

# ============
# F1 Score 그래프 그리기
# ============

plt.subplot(1, 3, 3)

plt.plot(epochs_range, train_f1, label="Train F1 Score")
plt.plot(epochs_range, val_f1, linestyle="--", label="Val F1 Score")
plt.plot(epochs_range, test_f1, linestyle=":", label="Test F1 Score")

plt.xlabel("Epoch")
plt.ylabel("F1 Score")
plt.title("F1 Score Curves")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# %%
# ============================================================
# Modality Ablation Study
# Text / Audio / Video / Fusion 조합 비교
# ============================================================

feature_sets = {
    "Text only": X_text,
    "Audio only": X_audio,
    "Video only": X_video,
    "Text + Audio": torch.cat([X_text, X_audio], dim=1),
    "Text + Video": torch.cat([X_text, X_video], dim=1),
    "Audio + Video": torch.cat([X_audio, X_video], dim=1),
    "Text + Audio + Video": torch.cat([X_text, X_audio, X_video], dim=1)
}

results = []

for model_name, fused in feature_sets.items():
    print("\n==============================")
    print(f"Training: {model_name}")
    print("==============================")

    input_dim = fused.shape[1]

    # 기존과 같은 split 사용
    X_train = fused[train_idx]
    y_train = y[train_idx]

    X_val = fused[val_idx]
    y_val = y[val_idx]

    X_test = fused[test_idx]
    y_test = y[test_idx]

    train_loader = DataLoader(
        TensorDataset(X_train, y_train),
        batch_size=32,
        shuffle=True
    )

    val_loader = DataLoader(
        TensorDataset(X_val, y_val),
        batch_size=32,
        shuffle=False
    )

    test_loader = DataLoader(
        TensorDataset(X_test, y_test),
        batch_size=32,
        shuffle=False
    )

    # 기존 MLP 구조 그대로 사용
    mlp = nn.Sequential(
        nn.Linear(input_dim, 256),
        nn.ReLU(),
        nn.Dropout(0.3),
        nn.Linear(256, 2)
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(mlp.parameters(), lr=0.001)

    best_val_loss = float("inf")
    best_model_state = None

    for epoch in range(20):
        mlp.train()
        train_loss = 0

        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()

            outputs = mlp(X_batch)
            loss = criterion(outputs, y_batch)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        val_loss, val_acc, val_prec, val_rec, val_f1 = evaluate(mlp, val_loader)

        print(
            f"Epoch [{epoch+1}/20] "
            f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, Val F1: {val_f1:.4f}"
        )

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = mlp.state_dict()

    # best validation 모델로 test 평가
    mlp.load_state_dict(best_model_state)

    test_loss, test_acc, test_prec, test_rec, test_f1 = evaluate(mlp, test_loader)

    results.append({
        "Model": model_name,
        "Input Dim": input_dim,
        "Test Loss": test_loss,
        "Test Acc": test_acc,
        "Test Precision": test_prec,
        "Test Recall": test_rec,
        "Test F1": test_f1
    })

# 결과표 확인
results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by="Test F1", ascending=False)

results_df
# Out:
# ==============================
# Training: Text only
# ==============================
# Epoch [1/20] Val Loss: 0.3045, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [2/20] Val Loss: 0.3176, Val Acc: 0.9027, Val F1: 0.8912
# Epoch [3/20] Val Loss: 0.3039, Val Acc: 0.9027, Val F1: 0.8919
# Epoch [4/20] Val Loss: 0.3084, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [5/20] Val Loss: 0.3052, Val Acc: 0.8997, Val F1: 0.8904
# Epoch [6/20] Val Loss: 0.3009, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [7/20] Val Loss: 0.2995, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [8/20] Val Loss: 0.3081, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [9/20] Val Loss: 0.3028, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [10/20] Val Loss: 0.3141, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [11/20] Val Loss: 0.3017, Val Acc: 0.8997, Val F1: 0.8889
# Epoch [12/20] Val Loss: 0.3048, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [13/20] Val Loss: 0.3033, Val Acc: 0.8997, Val F1: 0.8889
# Epoch [14/20] Val Loss: 0.3049, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [15/20] Val Loss: 0.3180, Val Acc: 0.8967, Val F1: 0.8874
# Epoch [16/20] Val Loss: 0.3160, Val Acc: 0.8997, Val F1: 0.8904
# Epoch [17/20] Val Loss: 0.3167, Val Acc: 0.9027, Val F1: 0.8919
# Epoch [18/20] Val Loss: 0.3055, Val Acc: 0.8967, Val F1: 0.8859
# Epoch [19/20] Val Loss: 0.3019, Val Acc: 0.8936, Val F1: 0.8822
# Epoch [20/20] Val Loss: 0.3158, Val Acc: 0.8997, Val F1: 0.8889
#
# ==============================
# Training: Audio only
# ==============================
# Epoch [1/20] Val Loss: 0.6145, Val Acc: 0.6474, Val F1: 0.6209
# Epoch [2/20] Val Loss: 0.6194, Val Acc: 0.6444, Val F1: 0.6589
# Epoch [3/20] Val Loss: 0.6189, Val Acc: 0.6474, Val F1: 0.6778
# Epoch [4/20] Val Loss: 0.6238, Val Acc: 0.6444, Val F1: 0.6846
# Epoch [5/20] Val Loss: 0.6146, Val Acc: 0.6535, Val F1: 0.6833
# Epoch [6/20] Val Loss: 0.6007, Val Acc: 0.6565, Val F1: 0.6725
# Epoch [7/20] Val Loss: 0.6014, Val Acc: 0.6535, Val F1: 0.6545
# Epoch [8/20] Val Loss: 0.5955, Val Acc: 0.6565, Val F1: 0.6480
# Epoch [9/20] Val Loss: 0.6052, Val Acc: 0.6687, Val F1: 0.6822
# Epoch [10/20] Val Loss: 0.5942, Val Acc: 0.6444, Val F1: 0.6238
# Epoch [11/20] Val Loss: 0.6038, Val Acc: 0.6505, Val F1: 0.6667
# Epoch [12/20] Val Loss: 0.5958, Val Acc: 0.6565, Val F1: 0.6502
# Epoch [13/20] Val Loss: 0.5986, Val Acc: 0.6444, Val F1: 0.6262
# Epoch [14/20] Val Loss: 0.5888, Val Acc: 0.6596, Val F1: 0.6111
# Epoch [15/20] Val Loss: 0.5898, Val Acc: 0.6505, Val F1: 0.6483
# Epoch [16/20] Val Loss: 0.5974, Val Acc: 0.6626, Val F1: 0.6520
# Epoch [17/20] Val Loss: 0.6057, Val Acc: 0.6474, Val F1: 0.6628
# Epoch [18/20] Val Loss: 0.5987, Val Acc: 0.6505, Val F1: 0.6417
# Epoch [19/20] Val Loss: 0.6009, Val Acc: 0.6474, Val F1: 0.6329
# Epoch [20/20] Val Loss: 0.6064, Val Acc: 0.6596, Val F1: 0.6543
#
# ==============================
# Training: Video only
# ==============================
# c:\Users\User\AppData\Local\anaconda3\envs\main\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch [1/20] Val Loss: 0.6963, Val Acc: 0.5532, Val F1: 0.0000
# Epoch [2/20] Val Loss: 0.7120, Val Acc: 0.4438, Val F1: 0.6115
# Epoch [3/20] Val Loss: 0.7014, Val Acc: 0.4498, Val F1: 0.6141
# Epoch [4/20] Val Loss: 0.7001, Val Acc: 0.4590, Val F1: 0.6164
# Epoch [5/20] Val Loss: 0.6945, Val Acc: 0.5137, Val F1: 0.5676
# Epoch [6/20] Val Loss: 0.6954, Val Acc: 0.4954, Val F1: 0.5514
# Epoch [7/20] Val Loss: 0.7101, Val Acc: 0.4498, Val F1: 0.6141
# Epoch [8/20] Val Loss: 0.7059, Val Acc: 0.4529, Val F1: 0.6137
# Epoch [9/20] Val Loss: 0.7008, Val Acc: 0.4863, Val F1: 0.6115
# Epoch [10/20] Val Loss: 0.7040, Val Acc: 0.4833, Val F1: 0.6101
# Epoch [11/20] Val Loss: 0.6965, Val Acc: 0.4772, Val F1: 0.6019
# Epoch [12/20] Val Loss: 0.6947, Val Acc: 0.4833, Val F1: 0.5550
# c:\Users\User\AppData\Local\anaconda3\envs\main\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\User\AppData\Local\anaconda3\envs\main\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch [13/20] Val Loss: 0.6915, Val Acc: 0.5532, Val F1: 0.0000
# Epoch [14/20] Val Loss: 0.6921, Val Acc: 0.5653, Val F1: 0.0530
# Epoch [15/20] Val Loss: 0.6919, Val Acc: 0.5532, Val F1: 0.0000
# c:\Users\User\AppData\Local\anaconda3\envs\main\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch [16/20] Val Loss: 0.6900, Val Acc: 0.5532, Val F1: 0.0000
# Epoch [17/20] Val Loss: 0.6971, Val Acc: 0.4772, Val F1: 0.5943
# Epoch [18/20] Val Loss: 0.6941, Val Acc: 0.5562, Val F1: 0.0135
# Epoch [19/20] Val Loss: 0.6945, Val Acc: 0.4711, Val F1: 0.5817
# Epoch [20/20] Val Loss: 0.6905, Val Acc: 0.5532, Val F1: 0.0000
#
# ==============================
# Training: Text + Audio
# ==============================
# Epoch [1/20] Val Loss: 0.2911, Val Acc: 0.9058, Val F1: 0.8956
# c:\Users\User\AppData\Local\anaconda3\envs\main\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\User\AppData\Local\anaconda3\envs\main\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch [2/20] Val Loss: 0.2843, Val Acc: 0.9027, Val F1: 0.8919
# Epoch [3/20] Val Loss: 0.2896, Val Acc: 0.9058, Val F1: 0.8956
# Epoch [4/20] Val Loss: 0.2912, Val Acc: 0.8997, Val F1: 0.8904
# Epoch [5/20] Val Loss: 0.2791, Val Acc: 0.9058, Val F1: 0.8949
# Epoch [6/20] Val Loss: 0.2933, Val Acc: 0.8967, Val F1: 0.8874
# Epoch [7/20] Val Loss: 0.2796, Val Acc: 0.9027, Val F1: 0.8926
# Epoch [8/20] Val Loss: 0.3191, Val Acc: 0.8936, Val F1: 0.8845
# Epoch [9/20] Val Loss: 0.2941, Val Acc: 0.8906, Val F1: 0.8816
# Epoch [10/20] Val Loss: 0.2930, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [11/20] Val Loss: 0.2813, Val Acc: 0.8936, Val F1: 0.8845
# Epoch [12/20] Val Loss: 0.2907, Val Acc: 0.8936, Val F1: 0.8845
# Epoch [13/20] Val Loss: 0.2863, Val Acc: 0.9058, Val F1: 0.8956
# Epoch [14/20] Val Loss: 0.2893, Val Acc: 0.8936, Val F1: 0.8845
# Epoch [15/20] Val Loss: 0.2873, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [16/20] Val Loss: 0.2800, Val Acc: 0.9058, Val F1: 0.8963
# Epoch [17/20] Val Loss: 0.2908, Val Acc: 0.8997, Val F1: 0.8904
# Epoch [18/20] Val Loss: 0.3009, Val Acc: 0.8936, Val F1: 0.8845
# Epoch [19/20] Val Loss: 0.3019, Val Acc: 0.9058, Val F1: 0.8949
# Epoch [20/20] Val Loss: 0.3015, Val Acc: 0.8936, Val F1: 0.8845
#
# ==============================
# Training: Text + Video
# ==============================
# Epoch [1/20] Val Loss: 0.3175, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [2/20] Val Loss: 0.3113, Val Acc: 0.8967, Val F1: 0.8851
# Epoch [3/20] Val Loss: 0.3173, Val Acc: 0.8997, Val F1: 0.8881
# Epoch [4/20] Val Loss: 0.3028, Val Acc: 0.8997, Val F1: 0.8889
# Epoch [5/20] Val Loss: 0.3165, Val Acc: 0.9027, Val F1: 0.8926
# Epoch [6/20] Val Loss: 0.3154, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [7/20] Val Loss: 0.3295, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [8/20] Val Loss: 0.3260, Val Acc: 0.8936, Val F1: 0.8845
# Epoch [9/20] Val Loss: 0.3086, Val Acc: 0.8997, Val F1: 0.8889
# Epoch [10/20] Val Loss: 0.3100, Val Acc: 0.8967, Val F1: 0.8836
# Epoch [11/20] Val Loss: 0.3030, Val Acc: 0.9027, Val F1: 0.8912
# Epoch [12/20] Val Loss: 0.3203, Val Acc: 0.8936, Val F1: 0.8837
# Epoch [13/20] Val Loss: 0.3131, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [14/20] Val Loss: 0.3117, Val Acc: 0.8967, Val F1: 0.8844
# Epoch [15/20] Val Loss: 0.3089, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [16/20] Val Loss: 0.3056, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [17/20] Val Loss: 0.3111, Val Acc: 0.8967, Val F1: 0.8867
# Epoch [18/20] Val Loss: 0.3118, Val Acc: 0.8967, Val F1: 0.8844
# Epoch [19/20] Val Loss: 0.3292, Val Acc: 0.8967, Val F1: 0.8874
# Epoch [20/20] Val Loss: 0.3077, Val Acc: 0.8936, Val F1: 0.8829
#
# ==============================
# Training: Audio + Video
# ==============================
# Epoch [1/20] Val Loss: 0.6266, Val Acc: 0.6231, Val F1: 0.5231
# Epoch [2/20] Val Loss: 0.6259, Val Acc: 0.6292, Val F1: 0.6039
# Epoch [3/20] Val Loss: 0.6168, Val Acc: 0.6413, Val F1: 0.4870
# Epoch [4/20] Val Loss: 0.6369, Val Acc: 0.6170, Val F1: 0.6595
# Epoch [5/20] Val Loss: 0.6109, Val Acc: 0.6565, Val F1: 0.6565
# Epoch [6/20] Val Loss: 0.6102, Val Acc: 0.6292, Val F1: 0.5271
# Epoch [7/20] Val Loss: 0.6083, Val Acc: 0.6687, Val F1: 0.6330
# Epoch [8/20] Val Loss: 0.6023, Val Acc: 0.6474, Val F1: 0.5766
# Epoch [9/20] Val Loss: 0.6245, Val Acc: 0.6444, Val F1: 0.6812
# Epoch [10/20] Val Loss: 0.6494, Val Acc: 0.6353, Val F1: 0.6667
# Epoch [11/20] Val Loss: 0.6034, Val Acc: 0.6535, Val F1: 0.6369
# Epoch [12/20] Val Loss: 0.6093, Val Acc: 0.6565, Val F1: 0.6523
# Epoch [13/20] Val Loss: 0.6009, Val Acc: 0.6748, Val F1: 0.6492
# Epoch [14/20] Val Loss: 0.6152, Val Acc: 0.6535, Val F1: 0.6743
# Epoch [15/20] Val Loss: 0.6114, Val Acc: 0.6353, Val F1: 0.6341
# Epoch [16/20] Val Loss: 0.6038, Val Acc: 0.6413, Val F1: 0.6093
# Epoch [17/20] Val Loss: 0.6130, Val Acc: 0.6565, Val F1: 0.6852
# Epoch [18/20] Val Loss: 0.6113, Val Acc: 0.6292, Val F1: 0.6065
# Epoch [19/20] Val Loss: 0.6003, Val Acc: 0.6505, Val F1: 0.5756
# Epoch [20/20] Val Loss: 0.6065, Val Acc: 0.6474, Val F1: 0.6647
#
# ==============================
# Training: Text + Audio + Video
# ==============================
# Epoch [1/20] Val Loss: 0.3006, Val Acc: 0.8967, Val F1: 0.8874
# Epoch [2/20] Val Loss: 0.2962, Val Acc: 0.9027, Val F1: 0.8919
# Epoch [3/20] Val Loss: 0.3013, Val Acc: 0.8997, Val F1: 0.8874
# Epoch [4/20] Val Loss: 0.3165, Val Acc: 0.8936, Val F1: 0.8852
# Epoch [5/20] Val Loss: 0.2977, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [6/20] Val Loss: 0.2861, Val Acc: 0.9027, Val F1: 0.8919
# Epoch [7/20] Val Loss: 0.2943, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [8/20] Val Loss: 0.2928, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [9/20] Val Loss: 0.2912, Val Acc: 0.9058, Val F1: 0.8956
# Epoch [10/20] Val Loss: 0.3202, Val Acc: 0.8967, Val F1: 0.8882
# Epoch [11/20] Val Loss: 0.2840, Val Acc: 0.9088, Val F1: 0.8986
# Epoch [12/20] Val Loss: 0.2853, Val Acc: 0.9027, Val F1: 0.8926
# Epoch [13/20] Val Loss: 0.3148, Val Acc: 0.8997, Val F1: 0.8911
# Epoch [14/20] Val Loss: 0.2898, Val Acc: 0.8997, Val F1: 0.8874
# Epoch [15/20] Val Loss: 0.2901, Val Acc: 0.8997, Val F1: 0.8896
# Epoch [16/20] Val Loss: 0.2924, Val Acc: 0.9027, Val F1: 0.8933
# Epoch [17/20] Val Loss: 0.2944, Val Acc: 0.8936, Val F1: 0.8845
# Epoch [18/20] Val Loss: 0.2862, Val Acc: 0.8997, Val F1: 0.8904
# Epoch [19/20] Val Loss: 0.2878, Val Acc: 0.8967, Val F1: 0.8874
# Epoch [20/20] Val Loss: 0.2988, Val Acc: 0.8906, Val F1: 0.8808
#                   Model  Input Dim  Test Loss  Test Acc  Test Precision  \
# 6  Text + Audio + Video        768   0.247921  0.903323        0.907975
# 3          Text + Audio        512   0.264886  0.897281        0.906832
# 4          Text + Video        512   0.277093  0.894260        0.911392
# 0             Text only        256   0.288188  0.888218        0.910256
# 5         Audio + Video        512   0.615118  0.676737        0.646465
# 1            Audio only        256   0.606639  0.667674        0.666667
# 2            Video only        256   0.691311  0.501511        0.000000
#
#    Test Recall   Test F1
# 6     0.896970  0.902439
# 3     0.884848  0.895706
# 4     0.872727  0.891641
# 0     0.860606  0.884735
# 5     0.775758  0.705234
# 1     0.666667  0.666667
# 2     0.000000  0.000000
