# %%
import os
import pickle
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"device: {device}")
# Out:
# device: cuda

# %%
video_path = r"C:\Users\User\Desktop\deeplearning\fusion\video_features_768.pkl"
audio_path = r"C:\Users\User\Desktop\deeplearning\fusion\audio_hubert_768.pkl"
text_path = r"C:\Users\User\Desktop\deeplearning\fusion\text_features_768(basic+earlystop).pkl"

# 2199개 샘플, 이미지 높이 224, 이미지 너비 224, RGB 3채널
with open(video_path, "rb") as f: 
    video_data = pickle.load(f)
X_video = video_data["features"]
X_video_labels = video_data["labels"] 



with open(audio_path, "rb") as f:
    audio_data = pickle.load(f)
X_audio = audio_data["audio_feat"]
X_audio_labels = audio_data["labels"]


text_data = torch.load(text_path,map_location=device)
X_text = text_data["features"]
X_text_labels = text_data["labels"]

# with open(text_path, "rb") as f:
#     text_data = pickle.load(f)
# X_text = text_data["features"]
# X_text_labels = text_data["labels"]

X_video_labels = torch.as_tensor(X_video_labels).long()
X_audio_labels = torch.as_tensor(X_audio_labels).long()
X_text_labels = torch.as_tensor(X_text_labels).long()


print(f"X_video      : {X_video.shape} ") # (224, 224, 3)
print(f"X_video_labels: (긍정 {X_video_labels.sum()} / 부정 {(X_video_labels==0).sum()})")

print(f"X_audio      : {X_audio.shape} ")
print(f"X_audio_labels: (긍정 {X_audio_labels.sum()} / 부정 {(X_audio_labels==0).sum()})")

print(f"X_text      : {X_text.shape} ")
print(f"X_text_labels: (긍정 {X_text_labels.sum()} / 부정 {(X_text_labels==0).sum()})")
# Out:
# X_video      : torch.Size([2199, 768])
# X_video_labels: (긍정 1080 / 부정 1119)
# X_audio      : torch.Size([2199, 768])
# X_audio_labels: (긍정 1080 / 부정 1119)
# X_text      : torch.Size([2199, 768])
# X_text_labels: (긍정 1080 / 부정 1119)

# %% [markdown]
# 그러나 라벨 분포가 video만 다르다

# %%
X_video_labels = torch.as_tensor(X_video_labels).cpu()
X_audio_labels = torch.as_tensor(X_audio_labels).cpu()
X_text_labels = torch.as_tensor(X_text_labels).cpu()

print(torch.equal(X_audio_labels, X_text_labels))
print(torch.equal(X_video_labels, X_text_labels))
print(torch.equal(X_video_labels, X_audio_labels))
# Out:
# True
# False
# False

# %% [markdown]
# feature 차원 기준 concat은 가능하나 label 기준 video 라벨이 달라 확인 필요
# 각자 차원수 맞춰왔으니 각 모달리티별 인코더 생략 가능

# %%
import torch.nn as nn

X_video = X_video.to(device)
X_audio = X_audio.to(device)
X_text = X_text.to(device)

# 세 모달리티 concat → MLP
fused = torch.cat([X_video, X_audio, X_text], dim=1)  # (N, 768)

input_dim = fused.shape[1]  # 768 + 768 + 768 = 2304


mlp = nn.Sequential(
    nn.Linear(input_dim, 256), 
    nn.ReLU(), 
    nn.Dropout(0.3),
    nn.Linear(256, 2)
)

y = torch.as_tensor(X_text_labels).long().to(device)  # (N,)

print(fused.shape)  # (N, 2304)
print(y.shape)
print(fused.device)
# Out:
# torch.Size([2199, 2304])
# torch.Size([2199])
# cuda:0

# %%
# train / val / test split
N = fused.shape[0]
indices = torch.randperm(N,device=device)

train_size = int(0.7 * N)
val_size = int(0.15 * N)

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size + val_size]
test_idx = indices[train_size + val_size:]

X_train, y_train = fused[train_idx], y[train_idx]
X_val, y_val = fused[val_idx], y[val_idx]
X_test, y_test = fused[test_idx], y[test_idx]

# %%
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score

# %%
#DataLoader
batch_size = 32

train_loader = DataLoader(
    TensorDataset(X_train, y_train),
    batch_size=32,
    shuffle=True
)

val_loader = DataLoader(
    TensorDataset(X_val, y_val),
    batch_size=32,
    shuffle=False
)
test_loader = DataLoader(
    TensorDataset(X_test, y_test),
    batch_size=32,
    shuffle=False
)

# %%
MLP = nn.Sequential(
    nn.Linear(input_dim, 256), 
    nn.BatchNorm1d(256),
    nn.ReLU(), 
    nn.Dropout(0.5),
    nn.Linear(256, 3)
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(MLP.parameters(), lr=1e-3)

# %%
def evaluate(model, data_loader):
    model.eval()
    all_preds = []
    all_labels = []
    total_loss = 0

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)

            total_loss += loss.item() 

            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(y_batch.cpu().numpy())

    avg_loss = total_loss / len(data_loader)
    acc = accuracy_score(all_labels, all_preds)
    prec = precision_score(all_labels, all_preds)
    rec = recall_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    
    return avg_loss, acc, prec, rec, f1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
mlp = mlp.to(device)

optimizer = optim.Adam(mlp.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

train_losses = []
val_losses = []


epochs = 20

for epoch in range(epochs):
    mlp.train()
    total_loss = 0

for X_batch, y_batch in train_loader:
    X_batch = X_batch.to(device)
    y_batch = y_batch.to(device)

    optimizer.zero_grad()

    outputs = mlp(X_batch)
    loss = criterion(outputs, y_batch)

    loss.backward()
    optimizer.step()

# %%
print(next(mlp.parameters()).device)
print(fused.device)
# Out:
# cuda:0
# cuda:0

# %%
mlp = mlp.to(fused.device)
optimizer = optim.Adam(mlp.parameters(), lr=1e-3)

print(next(mlp.parameters()).device)
print(fused.device)
# Out:
# cuda:0
# cuda:0

# %%
history = {
    "train_loss": [],
    "train_acc": [],
    "train_prec": [],
    "train_rec": [],
    "train_f1": [], 

    "val_loss": [],
    "val_acc": [],
    "val_prec": [],
    "val_rec": [],
    "val_f1": [],

    "test_loss": [],
    "test_acc": [],
    "test_prec": [],
    "test_rec": [],
    "test_f1": []
}

epochs = 20

# Early Stopping
best_val_loss = float("inf")
patience_counter = 0
patience = 4  
best_model_state = None
best_epoch = 0


for epoch in range(epochs):
    mlp.train()
    
    total_loss = 0

    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()

        outputs = mlp(X_batch)
        loss = criterion(outputs, y_batch)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    train_loss = total_loss / len(train_loader)

    train_loss, train_acc, train_prec, train_rec, train_f1 = evaluate(mlp, train_loader)
    val_loss, val_acc, val_prec, val_rec, val_f1 = evaluate(mlp, val_loader)
    test_loss, test_acc, test_prec, test_rec, test_f1 = evaluate(mlp, test_loader)

    # print(f"Epoch {epoch+1}/{epochs} ")
    # print(f"Loss: {train_loss:.4f} ")
    # print(f"Val Acc: {val_acc:.4f} ")
    # print(f"Val Prec: {val_prec:.4f} ")
    # print(f"Val Rec: {val_rec:.4f} ")
    # print(f"Val F1: {val_f1:.4f}")

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["train_prec"].append(train_prec)
    history["train_rec"].append(train_rec)
    history["train_f1"].append(train_f1)

    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)
    history["val_prec"].append(val_prec)
    history["val_rec"].append(val_rec)
    history["val_f1"].append(val_f1)

    history["test_loss"].append(test_loss)
    history["test_acc"].append(test_acc)
    history["test_prec"].append(test_prec)
    history["test_rec"].append(test_rec)
    history["test_f1"].append(test_f1)

    # Early Stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = mlp.state_dict().copy()
        best_epoch = epoch
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

    print(f"Epoch {epoch+1}/{epochs} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f} - Val Acc: {val_acc:.4f} - Val Prec: {val_prec:.4f} - Val Rec: {val_rec:.4f} - Val F1: {val_f1:.4f}")
# 가장 성능 좋은 모델 불러오기 (early stopping 기준)
mlp.load_state_dict(best_model_state)

train_loss, train_acc, train_prec, train_rec, train_f1 = evaluate(mlp, train_loader)
val_loss, val_acc, val_prec, val_rec, val_f1 = evaluate(mlp, val_loader)
test_loss, test_acc, test_prec, test_rec, test_f1 = evaluate(mlp, test_loader)

print("\n=====================결과=====================")
print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f} ,Train Prec: {train_prec:.4f} ,Train Rec: {train_rec:.4f} ,Train F1: {train_f1:.4f}")
print(f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f} ,Val Prec: {val_prec:.4f} ,Val Rec: {val_rec:.4f} ,Val F1: {val_f1:.4f}")
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f} ,Test Prec: {test_prec:.4f} ,Test Rec: {test_rec:.4f} ,Test F1: {test_f1:.4f}")
# Out:
# Epoch 1/20 - Train Loss: 0.2017 - Val Loss: 0.2343 - Val Acc: 0.9240 - Val Prec: 0.9176 - Val Rec: 0.9341 - Val F1: 0.9258
# Epoch 2/20 - Train Loss: 0.2079 - Val Loss: 0.2671 - Val Acc: 0.9271 - Val Prec: 0.9133 - Val Rec: 0.9461 - Val F1: 0.9294
# Epoch 3/20 - Train Loss: 0.1869 - Val Loss: 0.2399 - Val Acc: 0.9179 - Val Prec: 0.9167 - Val Rec: 0.9222 - Val F1: 0.9194
# Epoch 4/20 - Train Loss: 0.2125 - Val Loss: 0.2753 - Val Acc: 0.9271 - Val Prec: 0.9181 - Val Rec: 0.9401 - Val F1: 0.9290
# Early stopping at epoch 5
#
# =====================결과=====================
# Train Loss: 0.1797, Train Acc: 0.9298 ,Train Prec: 0.9435 ,Train Rec: 0.9109 ,Train F1: 0.9269
# Val Loss: 0.2465, Val Acc: 0.9271 ,Val Prec: 0.9231 ,Val Rec: 0.9341 ,Val F1: 0.9286
# Test Loss: 0.2402, Test Acc: 0.9275 ,Test Prec: 0.9202 ,Test Rec: 0.9317 ,Test F1: 0.9259

# %%
import matplotlib.pyplot as plt
import numpy as np

# ============
# x축 epoch 설정
# ============
epochs_range = range(1, len(history["train_loss"]) + 1)

# ============
# 0~1 값을 0~ 100 퍼센트로 변환
# ============
def to_percentage(values):
    values = np.array(values)
    if values.max() <= 1.5:
        return values * 100
    return values

train_acc = to_percentage(history["train_acc"])
val_acc = to_percentage(history["val_acc"])
test_acc = to_percentage(history["test_acc"])

train_f1 = to_percentage(history["train_f1"])
val_f1 = to_percentage(history["val_f1"])
test_f1 = to_percentage(history["test_f1"])

plt.figure(figsize=(18, 5))
plt.suptitle("MLP Middle Fusion(768)_text basic", fontsize=14)


# ============
# Loss 그래프 그리기
# ============

plt.subplot(1, 3, 1)

plt.plot(epochs_range, history["train_loss"], label="Train Loss")
plt.plot(epochs_range, history["val_loss"], linestyle="--", label="Val Loss")
plt.plot(epochs_range, history["test_loss"], linestyle=":", label="Test Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curves")
plt.legend()
plt.grid(True)


# ============
# Accuracy 그래프 그리기
# ============
plt.subplot(1, 3, 2)

plt.plot(epochs_range, train_acc, label="Train Accuracy")
plt.plot(epochs_range, val_acc, linestyle="--", label="Val Accuracy")
plt.plot(epochs_range, test_acc, linestyle=":", label="Test Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy Curves")
plt.legend()
plt.grid(True)

# ============
# F1 Score 그래프 그리기
# ============

plt.subplot(1, 3, 3)

plt.plot(epochs_range, train_f1, label="Train F1 Score")
plt.plot(epochs_range, val_f1, linestyle="--", label="Val F1 Score")
plt.plot(epochs_range, test_f1, linestyle=":", label="Test F1 Score")

plt.xlabel("Epoch")
plt.ylabel("F1 Score")
plt.title("F1 Score Curves")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# %%
# ============================================================
# Modality Ablation Study
# Text / Audio / Video / Fusion 조합 비교
# ============================================================

feature_sets = {
    "Text only": X_text,
    "Audio only": X_audio,
    "Video only": X_video,
    "Text + Audio": torch.cat([X_text, X_audio], dim=1),
    "Text + Video": torch.cat([X_text, X_video], dim=1),
    "Audio + Video": torch.cat([X_audio, X_video], dim=1),
    "Text + Audio + Video": torch.cat([X_text, X_audio, X_video], dim=1)
}

results = []

for model_name, fused in feature_sets.items():
    print("\n==============================")
    print(f"Training: {model_name}")
    print("==============================")

    input_dim = fused.shape[1]

    # 기존과 같은 split 사용
    X_train = fused[train_idx]
    y_train = y[train_idx]

    X_val = fused[val_idx]
    y_val = y[val_idx]

    X_test = fused[test_idx]
    y_test = y[test_idx]

    train_loader = DataLoader(
        TensorDataset(X_train, y_train),
        batch_size=32,
        shuffle=True
    )

    val_loader = DataLoader(
        TensorDataset(X_val, y_val),
        batch_size=32,
        shuffle=False
    )

    test_loader = DataLoader(
        TensorDataset(X_test, y_test),
        batch_size=32,
        shuffle=False
    )

    # 기존 MLP 구조 그대로 사용
    mlp = nn.Sequential(
        nn.Linear(input_dim, 256),
        nn.ReLU(),
        nn.Dropout(0.3),
        nn.Linear(256, 2)
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(mlp.parameters(), lr=0.001)

    best_val_loss = float("inf")
    best_model_state = None

    for epoch in range(20):
        mlp.train()
        train_loss = 0

        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()

            outputs = mlp(X_batch)
            loss = criterion(outputs, y_batch)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        val_loss, val_acc, val_prec, val_rec, val_f1 = evaluate(mlp, val_loader)

        print(
            f"Epoch [{epoch+1}/20] "
            f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, Val F1: {val_f1:.4f}"
        )

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = mlp.state_dict()

    # best validation 모델로 test 평가
    mlp.load_state_dict(best_model_state)

    test_loss, test_acc, test_prec, test_rec, test_f1 = evaluate(mlp, test_loader)

    results.append({
        "Model": model_name,
        "Input Dim": input_dim,
        "Test Loss": test_loss,
        "Test Acc": test_acc,
        "Test Precision": test_prec,
        "Test Recall": test_rec,
        "Test F1": test_f1
    })

# 결과표 확인
results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by="Test F1", ascending=False)

results_df
# Out:
# ==============================
# Training: Text only
# ==============================
# Epoch [1/20] Val Loss: 0.2389, Val Acc: 0.9271, Val F1: 0.9286
# Epoch [2/20] Val Loss: 0.2381, Val Acc: 0.9240, Val F1: 0.9254
# Epoch [3/20] Val Loss: 0.2416, Val Acc: 0.9271, Val F1: 0.9286
# Epoch [4/20] Val Loss: 0.2423, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [5/20] Val Loss: 0.2452, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [6/20] Val Loss: 0.2458, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [7/20] Val Loss: 0.2363, Val Acc: 0.9301, Val F1: 0.9318
# Epoch [8/20] Val Loss: 0.2368, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [9/20] Val Loss: 0.2369, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [10/20] Val Loss: 0.2395, Val Acc: 0.9301, Val F1: 0.9322
# Epoch [11/20] Val Loss: 0.2356, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [12/20] Val Loss: 0.2355, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [13/20] Val Loss: 0.2589, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [14/20] Val Loss: 0.2362, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [15/20] Val Loss: 0.2559, Val Acc: 0.9301, Val F1: 0.9322
# Epoch [16/20] Val Loss: 0.2379, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [17/20] Val Loss: 0.2408, Val Acc: 0.9301, Val F1: 0.9322
# Epoch [18/20] Val Loss: 0.2448, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [19/20] Val Loss: 0.2476, Val Acc: 0.9301, Val F1: 0.9322
# Epoch [20/20] Val Loss: 0.2549, Val Acc: 0.9331, Val F1: 0.9349
#
# ==============================
# Training: Audio only
# ==============================
# Epoch [1/20] Val Loss: 0.6592, Val Acc: 0.6413, Val F1: 0.6590
# Epoch [2/20] Val Loss: 0.6360, Val Acc: 0.6778, Val F1: 0.6901
# Epoch [3/20] Val Loss: 0.6173, Val Acc: 0.6778, Val F1: 0.6768
# Epoch [4/20] Val Loss: 0.6115, Val Acc: 0.6900, Val F1: 0.7167
# Epoch [5/20] Val Loss: 0.6289, Val Acc: 0.6565, Val F1: 0.5670
# Epoch [6/20] Val Loss: 0.6076, Val Acc: 0.6869, Val F1: 0.6709
# Epoch [7/20] Val Loss: 0.5950, Val Acc: 0.6748, Val F1: 0.6825
# Epoch [8/20] Val Loss: 0.6102, Val Acc: 0.6960, Val F1: 0.6689
# Epoch [9/20] Val Loss: 0.6025, Val Acc: 0.6900, Val F1: 0.7198
# Epoch [10/20] Val Loss: 0.6080, Val Acc: 0.6930, Val F1: 0.6645
# Epoch [11/20] Val Loss: 0.6199, Val Acc: 0.6596, Val F1: 0.6000
# Epoch [12/20] Val Loss: 0.6121, Val Acc: 0.6930, Val F1: 0.6645
# Epoch [13/20] Val Loss: 0.6215, Val Acc: 0.6991, Val F1: 0.7163
# Epoch [14/20] Val Loss: 0.5978, Val Acc: 0.7082, Val F1: 0.7193
# Epoch [15/20] Val Loss: 0.5975, Val Acc: 0.7021, Val F1: 0.7030
# Epoch [16/20] Val Loss: 0.6244, Val Acc: 0.6991, Val F1: 0.7080
# Epoch [17/20] Val Loss: 0.6199, Val Acc: 0.6991, Val F1: 0.6775
# Epoch [18/20] Val Loss: 0.6334, Val Acc: 0.6930, Val F1: 0.6710
# Epoch [19/20] Val Loss: 0.6246, Val Acc: 0.7021, Val F1: 0.6879
# Epoch [20/20] Val Loss: 0.6203, Val Acc: 0.7021, Val F1: 0.7101
#
# ==============================
# Training: Video only
# ==============================
# Epoch [1/20] Val Loss: 0.6556, Val Acc: 0.5927, Val F1: 0.6927
# Epoch [2/20] Val Loss: 0.6215, Val Acc: 0.6322, Val F1: 0.6513
# Epoch [3/20] Val Loss: 0.6256, Val Acc: 0.6383, Val F1: 0.6757
# Epoch [4/20] Val Loss: 0.6113, Val Acc: 0.6626, Val F1: 0.6959
# Epoch [5/20] Val Loss: 0.6256, Val Acc: 0.6140, Val F1: 0.6254
# Epoch [6/20] Val Loss: 0.6350, Val Acc: 0.6231, Val F1: 0.5118
# Epoch [7/20] Val Loss: 0.6462, Val Acc: 0.5836, Val F1: 0.5292
# Epoch [8/20] Val Loss: 0.6103, Val Acc: 0.6505, Val F1: 0.6567
# Epoch [9/20] Val Loss: 0.6128, Val Acc: 0.6626, Val F1: 0.6520
# Epoch [10/20] Val Loss: 0.6962, Val Acc: 0.5866, Val F1: 0.4603
# Epoch [11/20] Val Loss: 0.6163, Val Acc: 0.6292, Val F1: 0.6347
# Epoch [12/20] Val Loss: 0.5920, Val Acc: 0.6717, Val F1: 0.6707
# Epoch [13/20] Val Loss: 0.6123, Val Acc: 0.6778, Val F1: 0.6989
# Epoch [14/20] Val Loss: 0.6626, Val Acc: 0.6231, Val F1: 0.6416
# Epoch [15/20] Val Loss: 0.6230, Val Acc: 0.6535, Val F1: 0.6919
# Epoch [16/20] Val Loss: 0.6044, Val Acc: 0.6778, Val F1: 0.6667
# Epoch [17/20] Val Loss: 0.6177, Val Acc: 0.6657, Val F1: 0.6746
# Epoch [18/20] Val Loss: 0.6712, Val Acc: 0.6383, Val F1: 0.5939
# Epoch [19/20] Val Loss: 0.6516, Val Acc: 0.6535, Val F1: 0.6096
# Epoch [20/20] Val Loss: 0.6508, Val Acc: 0.6626, Val F1: 0.6647
#
# ==============================
# Training: Text + Audio
# ==============================
# Epoch [1/20] Val Loss: 0.2624, Val Acc: 0.9271, Val F1: 0.9294
# Epoch [2/20] Val Loss: 0.2581, Val Acc: 0.9149, Val F1: 0.9152
# Epoch [3/20] Val Loss: 0.2799, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [4/20] Val Loss: 0.2436, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [5/20] Val Loss: 0.2364, Val Acc: 0.9271, Val F1: 0.9286
# Epoch [6/20] Val Loss: 0.2485, Val Acc: 0.9301, Val F1: 0.9322
# Epoch [7/20] Val Loss: 0.2366, Val Acc: 0.9301, Val F1: 0.9322
# Epoch [8/20] Val Loss: 0.2434, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [9/20] Val Loss: 0.2364, Val Acc: 0.9240, Val F1: 0.9254
# Epoch [10/20] Val Loss: 0.2462, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [11/20] Val Loss: 0.2396, Val Acc: 0.9119, Val F1: 0.9124
# Epoch [12/20] Val Loss: 0.2661, Val Acc: 0.9271, Val F1: 0.9294
# Epoch [13/20] Val Loss: 0.2312, Val Acc: 0.9179, Val F1: 0.9184
# Epoch [14/20] Val Loss: 0.2393, Val Acc: 0.9271, Val F1: 0.9294
# Epoch [15/20] Val Loss: 0.3151, Val Acc: 0.9271, Val F1: 0.9294
# Epoch [16/20] Val Loss: 0.2866, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [17/20] Val Loss: 0.2433, Val Acc: 0.9271, Val F1: 0.9290
# Epoch [18/20] Val Loss: 0.2427, Val Acc: 0.9301, Val F1: 0.9318
# Epoch [19/20] Val Loss: 0.2435, Val Acc: 0.9149, Val F1: 0.9157
# Epoch [20/20] Val Loss: 0.2375, Val Acc: 0.9179, Val F1: 0.9194
#
# ==============================
# Training: Text + Video
# ==============================
# Epoch [1/20] Val Loss: 0.2330, Val Acc: 0.9149, Val F1: 0.9167
# Epoch [2/20] Val Loss: 0.2334, Val Acc: 0.9179, Val F1: 0.9189
# Epoch [3/20] Val Loss: 0.2327, Val Acc: 0.9179, Val F1: 0.9194
# Epoch [4/20] Val Loss: 0.2272, Val Acc: 0.9240, Val F1: 0.9263
# Epoch [5/20] Val Loss: 0.2390, Val Acc: 0.9210, Val F1: 0.9231
# Epoch [6/20] Val Loss: 0.2468, Val Acc: 0.9058, Val F1: 0.9058
# Epoch [7/20] Val Loss: 0.2371, Val Acc: 0.9240, Val F1: 0.9254
# Epoch [8/20] Val Loss: 0.2451, Val Acc: 0.9240, Val F1: 0.9267
# Epoch [9/20] Val Loss: 0.2595, Val Acc: 0.9271, Val F1: 0.9302
# Epoch [10/20] Val Loss: 0.2359, Val Acc: 0.9301, Val F1: 0.9326
# Epoch [11/20] Val Loss: 0.2837, Val Acc: 0.9271, Val F1: 0.9290
# Epoch [12/20] Val Loss: 0.2663, Val Acc: 0.9271, Val F1: 0.9286
# Epoch [13/20] Val Loss: 0.2680, Val Acc: 0.9331, Val F1: 0.9349
# Epoch [14/20] Val Loss: 0.2353, Val Acc: 0.9240, Val F1: 0.9254
# Epoch [15/20] Val Loss: 0.2441, Val Acc: 0.9179, Val F1: 0.9199
# Epoch [16/20] Val Loss: 0.2656, Val Acc: 0.9210, Val F1: 0.9226
# Epoch [17/20] Val Loss: 0.2676, Val Acc: 0.9058, Val F1: 0.9046
# Epoch [18/20] Val Loss: 0.2609, Val Acc: 0.9271, Val F1: 0.9294
# Epoch [19/20] Val Loss: 0.2567, Val Acc: 0.9210, Val F1: 0.9235
# Epoch [20/20] Val Loss: 0.3121, Val Acc: 0.9240, Val F1: 0.9280
#
# ==============================
# Training: Audio + Video
# ==============================
# Epoch [1/20] Val Loss: 0.6632, Val Acc: 0.5866, Val F1: 0.3874
# Epoch [2/20] Val Loss: 0.6211, Val Acc: 0.6413, Val F1: 0.6289
# Epoch [3/20] Val Loss: 0.6252, Val Acc: 0.6170, Val F1: 0.5685
# Epoch [4/20] Val Loss: 0.5834, Val Acc: 0.6778, Val F1: 0.7072
# Epoch [5/20] Val Loss: 0.5799, Val Acc: 0.6839, Val F1: 0.7263
# Epoch [6/20] Val Loss: 0.5539, Val Acc: 0.6960, Val F1: 0.7253
# Epoch [7/20] Val Loss: 0.5860, Val Acc: 0.6900, Val F1: 0.6434
# Epoch [8/20] Val Loss: 0.6115, Val Acc: 0.6626, Val F1: 0.7259
# Epoch [9/20] Val Loss: 0.5675, Val Acc: 0.6839, Val F1: 0.7111
# Epoch [10/20] Val Loss: 0.5761, Val Acc: 0.6778, Val F1: 0.7181
# Epoch [11/20] Val Loss: 0.5534, Val Acc: 0.7173, Val F1: 0.7240
# Epoch [12/20] Val Loss: 0.5588, Val Acc: 0.6991, Val F1: 0.6991
# Epoch [13/20] Val Loss: 0.6128, Val Acc: 0.6991, Val F1: 0.6857
# Epoch [14/20] Val Loss: 0.6433, Val Acc: 0.6960, Val F1: 0.6429
# Epoch [15/20] Val Loss: 0.5543, Val Acc: 0.7264, Val F1: 0.7205
# Epoch [16/20] Val Loss: 0.5844, Val Acc: 0.6960, Val F1: 0.7326
# Epoch [17/20] Val Loss: 0.5886, Val Acc: 0.6991, Val F1: 0.6972
# Epoch [18/20] Val Loss: 0.5953, Val Acc: 0.7082, Val F1: 0.7209
# Epoch [19/20] Val Loss: 0.6308, Val Acc: 0.7082, Val F1: 0.6667
# Epoch [20/20] Val Loss: 0.5977, Val Acc: 0.6839, Val F1: 0.7219
#
# ==============================
# Training: Text + Audio + Video
# ==============================
# Epoch [1/20] Val Loss: 0.2409, Val Acc: 0.9179, Val F1: 0.9179
# Epoch [2/20] Val Loss: 0.2302, Val Acc: 0.9240, Val F1: 0.9263
# Epoch [3/20] Val Loss: 0.2369, Val Acc: 0.9271, Val F1: 0.9286
# Epoch [4/20] Val Loss: 0.2266, Val Acc: 0.9240, Val F1: 0.9263
# Epoch [5/20] Val Loss: 0.2502, Val Acc: 0.9271, Val F1: 0.9290
# Epoch [6/20] Val Loss: 0.2467, Val Acc: 0.9179, Val F1: 0.9199
# Epoch [7/20] Val Loss: 0.2611, Val Acc: 0.9271, Val F1: 0.9302
# Epoch [8/20] Val Loss: 0.2723, Val Acc: 0.9362, Val F1: 0.9384
# Epoch [9/20] Val Loss: 0.2898, Val Acc: 0.9179, Val F1: 0.9217
# Epoch [10/20] Val Loss: 0.2962, Val Acc: 0.9179, Val F1: 0.9222
# Epoch [11/20] Val Loss: 0.2523, Val Acc: 0.9240, Val F1: 0.9263
# Epoch [12/20] Val Loss: 0.2968, Val Acc: 0.9149, Val F1: 0.9191
# Epoch [13/20] Val Loss: 0.3407, Val Acc: 0.9058, Val F1: 0.9117
# Epoch [14/20] Val Loss: 0.2809, Val Acc: 0.9058, Val F1: 0.9058
# Epoch [15/20] Val Loss: 0.3084, Val Acc: 0.9301, Val F1: 0.9322
# Epoch [16/20] Val Loss: 0.3102, Val Acc: 0.9210, Val F1: 0.9231
# Epoch [17/20] Val Loss: 0.3218, Val Acc: 0.9301, Val F1: 0.9326
# Epoch [18/20] Val Loss: 0.3130, Val Acc: 0.8936, Val F1: 0.8955
# Epoch [19/20] Val Loss: 0.2996, Val Acc: 0.9119, Val F1: 0.9150
# Epoch [20/20] Val Loss: 0.3113, Val Acc: 0.9271, Val F1: 0.9290
#                   Model  Input Dim  Test Loss  Test Acc  Test Precision  \
# 0             Text only        768   0.249708  0.924471        0.904762
# 4          Text + Video       1536   0.310840  0.921450        0.899408
# 3          Text + Audio       1536   0.250456  0.921450        0.909091
# 6  Text + Audio + Video       2304   0.329801  0.918429        0.913580
# 1            Audio only        768   0.583320  0.716012        0.693642
# 5         Audio + Video       1536   0.672567  0.637462        0.601990
# 2            Video only        768   0.688076  0.631420        0.614035
#
#    Test Recall   Test F1
# 0     0.944099  0.924012
# 4     0.944099  0.921212
# 3     0.931677  0.920245
# 6     0.919255  0.916409
# 1     0.745342  0.718563
# 5     0.751553  0.668508
# 2     0.652174  0.632530
